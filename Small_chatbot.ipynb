# %% [markdown]
# <a href="https://colab.research.google.com/github/kheireldine/Machine-learning-Projects/blob/main/Small_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR-10 Dataset

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
# used a dictionary to represent an intents JSON file
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you?", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %%
import json
import string
import random 
import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer 
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

# %%
# list for training data
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[:, 0]))
train_y = np.array(list(training[:, 1]))

# %%
def clean_text(text): 
  tokens = nltk.word_tokenize(text)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def bag_of_words(text, vocab): 
  tokens = clean_text(text)
  bow = [0] * len(vocab)
  for w in tokens: 
    for idx, word in enumerate(vocab):
      if word == w: 
        bow[idx] = 1
  return np.array(bow)

def pred_class(text, vocab, labels): 
  bow = bag_of_words(text, vocab)
  result = model.predict(np.array([bow]))[0]
  thresh = 0.2
  y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]

  y_pred.sort(key=lambda x: x[1], reverse=True)
  return_list = []
  for r in y_pred:
    return_list.append(labels[r[0]])
  return return_list

def get_response(intents_list, intents_json): 
  tag = intents_list[0]
  list_of_intents = intents_json["intents"]
  for i in list_of_intents: 
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %%
# defining some parameters
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               5120
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 876ms/step - loss: 1.5816 - accuracy: 0.1579
# Epoch 2/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.4910 - accuracy: 0.4211
# Epoch 3/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.4659 - accuracy: 0.5263
# Epoch 4/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3263 - accuracy: 0.5263
# Epoch 5/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3183 - accuracy: 0.5789
# Epoch 6/200
# 1/1 [==============================] - 0s 6ms/step - loss: 1.1137 - accuracy: 0.8421
# Epoch 7/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.0011 - accuracy: 0.7895
# Epoch 8/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8800 - accuracy: 1.0000
# Epoch 9/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8157 - accuracy: 0.9474
# Epoch 10/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6513 - accuracy: 0.8947
# Epoch 11/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6649 - accuracy: 0.9474
# Epoch 12/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5502 - accuracy: 0.9474
# Epoch 13/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4181 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3227 - accuracy: 0.9474
# Epoch 15/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2372 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.3056 - accuracy: 0.8947
# Epoch 17/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1777 - accuracy: 1.0000
# Epoch 18/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1043 - accuracy: 1.0000
# Epoch 19/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0880 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2027 - accuracy: 0.8947
# Epoch 21/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 22/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1109 - accuracy: 0.9474
# Epoch 24/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0533 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0272 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0957 - accuracy: 0.9474
# Epoch 30/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1253 - accuracy: 0.9474
# Epoch 35/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0688 - accuracy: 0.9474
# Epoch 38/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0437 - accuracy: 0.9474
# Epoch 40/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0158 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1002 - accuracy: 0.9474
# Epoch 42/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1073 - accuracy: 0.9474
# Epoch 43/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0840 - accuracy: 0.9474
# Epoch 44/200
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1396 - accuracy: 0.8947
# Epoch 47/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0681 - accuracy: 0.9474
# Epoch 48/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8181e-04 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1133 - accuracy: 0.9474
# Epoch 52/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1020 - accuracy: 0.9474
# Epoch 59/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 6ms/step - loss: 8.2085e-04 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.9735e-04 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 7ms/step - loss: 6.7974e-04 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.2842e-04 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 10ms/step - loss: 3.7096e-04 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.6233e-05 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.3918e-04 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.2321e-04 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.0861e-04 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.3833e-04 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 11ms/step - loss: 4.8978e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.1733e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 19ms/step - loss: 3.9504e-05 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.2760e-04 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9966e-04 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.1997e-04 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0390 - accuracy: 0.9474
# Epoch 94/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 16ms/step - loss: 1.5947e-04 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.3419e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 15ms/step - loss: 7.3219e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.5526e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 35ms/step - loss: 6.2535e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.8074e-05 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 16ms/step - loss: 7.8089e-05 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 18ms/step - loss: 4.4057e-05 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.6395e-05 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.6849e-04 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.8516e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.2837e-05 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.2421e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 7ms/step - loss: 2.2123e-04 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1656 - accuracy: 0.9474
# Epoch 123/200
# 1/1 [==============================] - 0s 19ms/step - loss: 5.7770e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 13ms/step - loss: 7.6431e-04 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.6786e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.9329e-05 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.1341e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 9ms/step - loss: 8.1685e-04 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9768e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4741e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 10ms/step - loss: 7.1944e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.1034e-04 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.9211e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 7ms/step - loss: 5.7851e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 8ms/step - loss: 8.3779e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.3227e-04 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 9ms/step - loss: 5.4700e-04 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 8ms/step - loss: 3.6952e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3053e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.5028e-04 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 20ms/step - loss: 2.2940e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.9278e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 10ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 10ms/step - loss: 2.1030e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.8320e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 7ms/step - loss: 3.7721e-04 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.2233e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 10ms/step - loss: 1.0818e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 23ms/step - loss: 6.1056e-05 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 10ms/step - loss: 4.0267e-04 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 21ms/step - loss: 1.5973e-04 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 9ms/step - loss: 9.8370e-05 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9397e-04 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 14ms/step - loss: 6.0292e-05 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 8ms/step - loss: 2.7684e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 21ms/step - loss: 6.2741e-06 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9577e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.1291e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.7912e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 14ms/step - loss: 8.5403e-05 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.3919e-06 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.9503e-05 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.5156e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 9ms/step - loss: 7.5098e-05 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 8ms/step - loss: 5.9822e-05 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.5849e-04 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 8ms/step - loss: 1.4618e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.0359e-04 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 9ms/step - loss: 2.1023e-05 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 7ms/step - loss: 7.0340e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 7ms/step - loss: 1.3827e-04 - accuracy: 1.0000

# %%
# running the chatbot
while True:
    message = input("")
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
# Out:
# Hello
# See you later
# hi
# How do you do?
# nothing
# Speak soon!
# fuck
# Speak soon!
# hey
# It was nice speaking to you
# bye
# Speak soon!
# hello
# Howdy Partner!
# how are you
# How do you do?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-19466bcd30c0> in <module>()
#       1 # running the chatbot
#       2 while True:
# ----> 3     message = input("")
#       4     intents = pred_class(message, words, classes)
#       5     result = get_response(intents, data)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
